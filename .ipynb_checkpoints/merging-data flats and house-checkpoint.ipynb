# %%
import numpy as np 
import pandas as pd

# %%
flats=pd.read_csv(r"C:\Users\umar\anaconda files\Major_project\Major_projects_data\flats_cleaned.csv")
house=pd.read_csv(r"C:\Users\umar\anaconda files\Major_project\Major_projects_data\house_cleaned.csv")

# %%
df=pd.concat([flats,house],ignore_index=True)
#yha apan ne concat kr diya data ko flats and house wale

# %%
df=df.sample(df.shape[0],ignore_index=True)
#here we r just simply mixing it randomly

# %%
df.shape
# Out:
# (3960, 20)

# %%
df.head()
# Out:
#                                      property_name property_type  \
# 0                 3 BHK Flat in Sector 102 Gurgaon          flat
# 1                  4 BHK Flat in Sector 54 Gurgaon          flat
# 2                  3 BHK Flat in Sector 77 Gurgaon          flat
# 3  6 Bedroom House for sale in Sushant Lok Phase 1         house
# 4           3 Bedroom House for sale in Hira Nagar         house
#
#                    society  price  price_per_sqft    area  \
# 0     emaar gurgaon greens   1.35          8181.0  1650.0
# 1                la lagune   6.75         21360.0  3160.0
# 2       emaar palm heights   2.25         11250.0  2000.0
# 3  ansal sushant lok plots   5.80         29974.0  1935.0
# 4              independent   1.05          9722.0  1080.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3         3
# 1  Super Built up area 3160(293.57 sq.m.)Built Up...        4         6
# ...

# %%
df.to_csv("gurgaon_properties.csv",index=False)
