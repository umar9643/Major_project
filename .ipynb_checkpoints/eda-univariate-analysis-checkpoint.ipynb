# %%
import  pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\umar\anaconda files\Major_project\Major_projects_data\gurgaon_properties_cleaned_v2.csv")

# %%
df.head(5)
# Out:
#   property_type                  society           sector  price  \
# 0          flat     emaar gurgaon greens       sector 102   1.35
# 1          flat                la lagune        sector 54   6.75
# 2          flat       emaar palm heights        sector 77   2.25
# 3         house  ansal sushant lok plots        sector 43   5.80
# 4         house              independent  sohna road road   6.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8181.0  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...
# 1         21360.0  3160.0  Super Built up area 3160(293.57 sq.m.)Built Up...
# 2         11250.0  2000.0             Super Built up area 2000(185.81 sq.m.)
# 3         29974.0  1935.0                        Plot area 215(179.77 sq.m.)
# 4          6944.0  9001.0                       Plot area 1000(836.13 sq.m.)
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# ...

# %%
df.shape
# Out:
# (3802, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3802 entries, 0 to 3801
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3802 non-null   object
#  1   society              3801 non-null   object
#  2   sector               3802 non-null   object
#  3   price                3785 non-null   float64
#  4   price_per_sqft       3785 non-null   float64
#  5   area                 3785 non-null   float64
#  6   areaWithType         3802 non-null   object
#  7   bedRoom              3802 non-null   int64
#  8   bathroom             3802 non-null   int64
#  9   balcony              3802 non-null   object
#  10  floorNum             3783 non-null   float64
#  11  facing               2697 non-null   object
#  12  agePossession        3802 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1733 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#   property_type                  society           sector  price  \
# 0          flat     emaar gurgaon greens       sector 102   1.35
# 1          flat                la lagune        sector 54   6.75
# 2          flat       emaar palm heights        sector 77   2.25
# 3         house  ansal sushant lok plots        sector 43   5.80
# 4         house              independent  sohna road road   6.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8181.0  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...
# 1         21360.0  3160.0  Super Built up area 3160(293.57 sq.m.)Built Up...
# 2         11250.0  2000.0             Super Built up area 2000(185.81 sq.m.)
# 3         29974.0  1935.0                        Plot area 215(179.77 sq.m.)
# 4          6944.0  9001.0                       Plot area 1000(836.13 sq.m.)
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# ...

# %% [markdown]
# # property type

# %%
df["property_type"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# **Observation**
# * Flats  are in majority  75% and there are  less no. of house(25%)
# * No missing values
